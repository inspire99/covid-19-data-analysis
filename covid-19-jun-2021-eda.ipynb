# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/coronavirus-spread-global/COVID-19 Global Jun week 4.csv
# /kaggle/input/covid19-global/COVID-19 Global Jun week 4.csv

# %%
data=pd.read_csv("../input/coronavirus-spread-global/COVID-19 Global Jun week 4.csv")
data
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 180817269
# 1    United States of America         Americas                  33285377
# 2                       India  South-East Asia                  30279331
# 3                      Brazil         Americas                  18386894
# 4                      France           Europe                   5660815
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# 0                                       2319.793864
# 1                                      10055.920000
# 2                                       2194.150000
# 3                                       8650.240000
# 4                                       8703.680000
# ..                                              ...
# 233                                        0.000000
# 234                                        0.000000
# 235                                        0.000000
# 236                                        0.000000
# 237                                        0.000000
#
#      Cases - newly reported in last 7 days  \
# 0                                  2570299
# 1                                    78351
# 2                                   344110
# 3                                   503144
# 4                                    10790
# ..                                     ...
# 233                                      0
# 234                                      0
# 235                                      0
# 236                                      0
# 237                                      0
#
#      Cases - newly reported in last 7 days per 100000 population  \
# 0                                            32.975633
# 1                                            23.670000
# 2                                            24.940000
# 3                                           236.710000
# 4                                            16.590000
# ..                                                 ...
# 233                                           0.000000
# 234                                           0.000000
# 235                                           0.000000
# 236                                           0.000000
# 237                                           0.000000
#
#      Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                     325138                    3923238
# 1                                          0                     598504
# 2                                      46148                     396730
# 3                                      64134                     512735
# 4                                       1460                     110063
# ..                                       ...                        ...
# 233                                        0                          0
# 234                                        0                          0
# 235                                        0                          0
# 236                                        0                          0
# 237                                        0                          0
#
#      Deaths - cumulative total per 100000 population  \
# 0                                          50.333154
# 1                                         180.820000
# 2                                          28.750000
# 3                                         241.220000
# 4                                         169.230000
# ..                                               ...
# 233                                         0.000000
# 234                                         0.000000
# 235                                         0.000000
# 236                                         0.000000
# 237                                         0.000000
#
#      Deaths - newly reported in last 7 days  \
# 0                                     55991
# 1                                      2356
# 2                                      8595
# 3                                     11935
# 4                                       223
# ..                                      ...
# 233                                       0
# 234                                       0
# 235                                       0
# 236                                       0
# 237                                       0
#
#      Deaths - newly reported in last 7 days per 100000 population  \
# 0                                             0.718336
# 1                                             0.710000
# 2                                             0.620000
# 3                                             5.610000
# 4                                             0.340000
# ..                                                 ...
# 233                                           0.000000
# 234                                           0.000000
# 235                                           0.000000
# 236                                           0.000000
# 237                                           0.000000
#
#      Deaths - newly reported in last 24 hours Transmission Classification
# 0                                        6467                         NaN
# 1                                           0      Community transmission
# 2                                         979           Clusters of cases
# 3                                        1593      Community transmission
# 4                                          46      Community transmission
# ..                                        ...                         ...
# 233                                         0                    No cases
# 234                                         0                    No cases
# 235                                         0                    No cases
# 236                                         0                    No cases
# 237                                         0                    No cases
#
# [238 rows x 13 columns]

# %%
data.shape
# Out:
# (238, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Name                                                          238 non-null    object
#  1   WHO Region                                                    237 non-null    object
#  2   Cases - cumulative total                                      238 non-null    int64
#  3   Cases - cumulative total per 100000 population                237 non-null    float64
#  4   Cases - newly reported in last 7 days                         238 non-null    int64
#  5   Cases - newly reported in last 7 days per 100000 population   237 non-null    float64
#  6   Cases - newly reported in last 24 hours                       238 non-null    int64
#  7   Deaths - cumulative total                                     238 non-null    int64
#  8   Deaths - cumulative total per 100000 population               237 non-null    float64
#  9   Deaths - newly reported in last 7 days                        238 non-null    int64
#  10  Deaths - newly reported in last 7 days per 100000 population  237 non-null    float64
#  11  Deaths - newly reported in last 24 hours                      238 non-null    int64
#  12  Transmission Classification                                   237 non-null    object
# dtypes: float64(4), int64(6), object(3)
# memory usage: 24.3+ KB

# %%
data.head(5)
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                 180817269
# 1  United States of America         Americas                  33285377
# 2                     India  South-East Asia                  30279331
# 3                    Brazil         Americas                  18386894
# 4                    France           Europe                   5660815
#
#    Cases - cumulative total per 100000 population  \
# 0                                     2319.793864
# 1                                    10055.920000
# 2                                     2194.150000
# 3                                     8650.240000
# 4                                     8703.680000
#
#    Cases - newly reported in last 7 days  \
# 0                                2570299
# 1                                  78351
# 2                                 344110
# 3                                 503144
# 4                                  10790
#
#    Cases - newly reported in last 7 days per 100000 population  \
# 0                                          32.975633
# 1                                          23.670000
# 2                                          24.940000
# 3                                         236.710000
# 4                                          16.590000
#
#    Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                   325138                    3923238
# 1                                        0                     598504
# 2                                    46148                     396730
# 3                                    64134                     512735
# 4                                     1460                     110063
#
#    Deaths - cumulative total per 100000 population  \
# 0                                        50.333154
# 1                                       180.820000
# 2                                        28.750000
# 3                                       241.220000
# 4                                       169.230000
#
#    Deaths - newly reported in last 7 days  \
# 0                                   55991
# 1                                    2356
# 2                                    8595
# 3                                   11935
# 4                                     223
#
#    Deaths - newly reported in last 7 days per 100000 population  \
# 0                                           0.718336
# 1                                           0.710000
# 2                                           0.620000
# 3                                           5.610000
# 4                                           0.340000
#
#    Deaths - newly reported in last 24 hours Transmission Classification
# 0                                      6467                         NaN
# 1                                         0      Community transmission
# 2                                       979           Clusters of cases
# 3                                      1593      Community transmission
# 4                                        46      Community transmission

# %%
data['Name']
# Out:
# 0                        Global
# 1      United States of America
# 2                         India
# 3                        Brazil
# 4                        France
#                  ...
# 233                Saint Helena
# 234                     Tokelau
# 235                       Tonga
# 236                Turkmenistan
# 237                      Tuvalu
# Name: Name, Length: 238, dtype: object

# %%
data.query('Name=="India"')
# Out:
#     Name       WHO Region  Cases - cumulative total  \
# 2  India  South-East Asia                  30279331
#
#    Cases - cumulative total per 100000 population  \
# 2                                         2194.15
#
#    Cases - newly reported in last 7 days  \
# 2                                 344110
#
#    Cases - newly reported in last 7 days per 100000 population  \
# 2                                              24.94
#
#    Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 2                                    46148                     396730
#
#    Deaths - cumulative total per 100000 population  \
# 2                                            28.75
#
#    Deaths - newly reported in last 7 days  \
# 2                                    8595
#
#    Deaths - newly reported in last 7 days per 100000 population  \
# 2                                               0.62
#
#    Deaths - newly reported in last 24 hours Transmission Classification
# 2                                       979           Clusters of cases

# %%
# !pip install git+git://github.com/geopandas/geopandas.git
# Out:
# Collecting git+git://github.com/geopandas/geopandas.git
#   Cloning git://github.com/geopandas/geopandas.git to /tmp/pip-req-build-burgc0zu
#   Running command git clone -q git://github.com/geopandas/geopandas.git /tmp/pip-req-build-burgc0zu
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.7/site-packages (from geopandas==0.9.0+38.gf50e2dd) (1.2.2)
# Requirement already satisfied: shapely>=1.6 in /opt/conda/lib/python3.7/site-packages (from geopandas==0.9.0+38.gf50e2dd) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in /opt/conda/lib/python3.7/site-packages (from geopandas==0.9.0+38.gf50e2dd) (1.8.18)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from geopandas==0.9.0+38.gf50e2dd) (2.6.1.post1)
# Requirement already satisfied: attrs>=17 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+38.gf50e2dd) (20.3.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+38.gf50e2dd) (2020.12.5)
# Requirement already satisfied: click<8,>=4.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+38.gf50e2dd) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+38.gf50e2dd) (0.7.1)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+38.gf50e2dd) (1.1.1)
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+38.gf50e2dd) (1.15.0)
# Requirement already satisfied: munch in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas==0.9.0+38.gf50e2dd) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas==0.9.0+38.gf50e2dd) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas==0.9.0+38.gf50e2dd) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas==0.9.0+38.gf50e2dd) (1.19.5)
# Building wheels for collected packages: geopandas
#   Building wheel for geopandas (setup.py) ... done
#   Created wheel for geopandas: filename=geopandas-0.9.0+38.gf50e2dd-py2.py3-none-any.whl size=996470 sha256=f705b5227505e2b91b5a98cc734a91e3607f59498443fc0614d3e2cdff72907b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-en6rdhxe/wheels/cf/3e/0b/6475054094c2b1ea054158ac1fdcf749fb92f5b512377e4cf8
# Successfully built geopandas
# Installing collected packages: geopandas
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 0.9.0
#     Uninstalling geopandas-0.9.0:
#       Successfully uninstalled geopandas-0.9.0
# Successfully installed geopandas-0.9.0+38.gf50e2dd
